# %% [markdown]
# <a href="https://colab.research.google.com/github/Atia6/Machine_Learning_Python/blob/main/Linear_Regression/LinearRegression_BostonHousing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
boston_df=pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv', sep =",")
boston_df.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.distplot(boston_df['medv'], hist = True)
plt.axvline(boston_df['medv'].mean(), linestyle='-')
plt.show()
# Out:
# <ipython-input-4-6548321fab2d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(boston_df['medv'], hist = True)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(boston_df.corr(method='pearson'), annot =True, cmap='RdPu')
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.scatter(boston_df['rm'], boston_df['medv'])
plt.show()

# %%
#correlation
plt.figure(figsize=(12,8))
sns.heatmap(boston_df.corr(method='pearson'), annot =True, cmap='RdPu')
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(boston_df['rm'], boston_df['medv'])
plt.show()

# %%
#data preprocessing
from sklearn.preprocessing import MinMaxScaler
Scaler =MinMaxScaler(feature_range = (0, 1))

# %%
X= boston_df.drop(['rad', 'medv'], axis =1)
Y = boston_df['medv']

# %%
X_Scaled = Scaler.fit_transform(X)

# %%
#Linear Regression
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X_Scaled, Y, test_size = 0.2 , random_state = 3)

from sklearn.linear_model import LinearRegression
lin_model= LinearRegression()
